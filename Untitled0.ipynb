# %% [markdown]
# <a href="https://colab.research.google.com/github/gilmark-red/Projeto-integrador/blob/1609-01/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

Temperatura_media = [24.5, 25.1, 23.8, 26.3, 27.0, 28.2, 26.8]

df_temperatura = pd.DataFrame({
    'Dia da Semana': Dias,
    'Temperatura Média': Temperatura_media
})

# Encontrar o dia mais quente
dia_mais_quente_idx = df_temperatura['Temperatura Média'].idxmax()

# Definir as cores para as barras
cores = ['green'] * len(df_temperatura) # Cor padrão: verde
cores[dia_mais_quente_idx] = 'orange' # Dia mais quente: laranja

plt.figure(figsize=(10, 6))
plt.bar(df_temperatura['Dia da Semana'], df_temperatura['Temperatura Média'], color=cores)
plt.xlabel('Dia da Semana')
plt.ylabel('Temperatura (ºC)')
plt.title('Temperatura Média por Dia da Semana')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Salvando no GitHub
#
# Para salvar este notebook no GitHub, você precisará ter o Git configurado no seu ambiente Colab e autenticado com sua conta do GitHub. Execute as células abaixo para salvar suas alterações.

# %%
# Execute esta célula para configurar o seu usuário e email do Git
# !git config --global user.name "Seu Nome de Usuário do GitHub"
# !git config --global user.email "seu.email@exemplo.com"

# Antes de executar esta célula, certifique-se de que o notebook está salvo no seu repositório Git no Google Drive ou que você clonou um repositório.
# Se o seu notebook for novo e ainda não estiver em um repositório, você precisará inicializar um:
# !git init
# !git add .
# !git commit -m "Primeiro commit"
# !git branch -M main
# !git remote add origin https://github.com/SEU_USUARIO/SEU_REPOSITORIO.git
# !git push -u origin main

# Se o notebook já está em um repositório, use os comandos abaixo para adicionar, fazer commit e enviar.
# Lembre-se de que você pode precisar configurar suas credenciais do Git ou usar um token de acesso pessoal.

# Substitua pelo caminho correto do seu notebook e mensagem de commit
notebook_path = "./seu_notebook.ipynb" # Altere para o nome do seu arquivo .ipynb
commit_message = "versao - Grafico Básico"

# Adiciona o notebook atualizado
# !git add {notebook_path}

# Faz o commit das alterações
# !git commit -m "{commit_message}"

# Envia as alterações para o repositório remoto (você pode precisar de autenticação)
# !git push

print(f"Notebook salvo no GitHub com a mensagem: '{commit_message}'")
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# Notebook salvo no GitHub com a mensagem: 'versao - Grafico Básico'
